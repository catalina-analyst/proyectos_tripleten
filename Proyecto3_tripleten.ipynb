# %% [markdown]
# **Comentario del Revisor**
#
# Hola!
#
# Soy Juan Manuel Romero, pero siéntete libre de llamarme Juanma. Soy code reviewer en Tripleten y hoy estaré revisando tu entrega.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Solo un aviso rápido: cuando estés revisando el proyecto, por favor deja mis comentarios originales tal como están. De esta manera, podemos seguir fácilmente el progreso y asegurarnos de que no se nos pase nada por alto. Y, si realizas algún cambio basado en mis comentarios, sería genial si pudieras resaltar esas actualizaciones para que se destaquen.
#
# Puedes encontrar mis comentarios en cajas verdes, amarillas o rojas como estas:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Éxito. Todo se ha hecho correctamente.
#
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
#
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Requiere corrección. El bloque requiere algunas correcciones. El trabajo no puede ser aceptado con los comentarios en rojo.
#
# </div>
#
# Puedes responderme usando esto:
#
# <div class="alert alert-block alert-info"> <b>Respuesta del estudiante.</b> <a class="tocSkip"></a> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>COMENTARIO GENERAL #1</b> <a class="tocSkip"></a>
#
# Felicidades Catalina! Tu trabajo es excelente.
#
# Has completado todos los items necesarios para aprobar la entrega.
#
# Sigue así!
#
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta sección de “Plan de solución” sigue siendo texto provisional. Por favor, añade tu propio plan breve para el Paso 1 (qué archivos vas a cargar, qué parámetros de `read_csv` vas a usar y por qué —p. ej., delimitador/typing— y qué comprobaciones vas a realizar después de la carga, como `info()`, `head()`, valores faltantes y duplicados).
#
# </div>

# %%
#primero se importan las librerias pandas para abrir dataframes
#después se importa pyplot para en un futuro poder generar gráficos
import pandas as pd
from matplotlib import pyplot as plt
# importar librerías

# %%
#se lee cada dataframe por separado, como tipo de archivo csv en este caso.
## Se usa el delimitador ; para que los datos queden bien separados en columnas.
pedidos_instacart = pd.read_csv("/datasets/instacart_orders.csv", sep=';')
productos = pd.read_csv("/datasets/products.csv", sep=';')
pasillo = pd.read_csv("/datasets/aisles.csv", sep=';')
departamentos = pd.read_csv("/datasets/departments.csv", sep=';')
pedidos = pd.read_csv("/datasets/order_products.csv", sep=';')
# leer conjuntos de datos en los DataFrames

# %%
# mostrar información del DataFrame
pedidos_instacart.info() #para mostrar las columnas, tipos de datos y valores no nulos.
#en la columna 6 (days_since_prior_order) hay valores ausentes
print(pedidos_instacart.head()) ##para ver cómo es la tabla, sus columnas y datos dentro de las columnas.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %%
# mostrar información del DataFrame
productos.info()
print(productos.head())
#en la columna 2 (product_name) hay valores ausentes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %%
# mostrar información del DataFrame
pasillo.info()
print(pasillo.head())
#este dataframe no tiene valores ausentes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# mostrar información del DataFrame
departamentos.info()
print(departamentos.tail()) #se puede usar head o tail para ver un pequeño vistazo de las columnas.
#dataframe sin valores ausentes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
#     department_id department
# 16             17  household
# 17             18     babies
# 18             19     snacks
# 19             20       deli
# 20             21    missing

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto! Es bueno incluir el parámetro `show_counts=True` al explorar el DataFrame `order_products`. Esto proporciona una visión más clara de los datos no nulos y es una buena práctica para datasets grandes.
#
# </div>

# %%
# mostrar información del DataFrame
pedidos.info(show_counts = True)
#ya que no se observan los valores no nulos con info(), se agrega la opción show_counts=True.
print(pedidos.head())
#están bien cargados los datos visualizando con head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Para la tabla grande `order_products`, la tarea espera que informes los conteos de valores no nulos. Considera usar `info(show_counts=True)` (o un enfoque equivalente) para que puedas verificar explícitamente los valores faltantes en lugar de indicar que no se muestran los conteos.
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
# - Primero había que fijarse en cómo estaban separados los datos en los distintos archivos, y corregirlo usando ";".
# - En general, varios archivos csv comparten mismas columnas como: product_id, order_id o aisle_id.
# - Hay tipos de datos tipo float, int y object, que posiblemente no sean dificiles de trabajar. Quizás algunos datos serán de variables categóricas y otros variables numéricas.
# - Hay dataframes con muchos datos y otros con muy pocos datos, habrá que saber porqué.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# Primero, a través de info() y head() se puede ver el tipo de dato de cada columna y se verificó que todas las columnas con _id son números enteros, que las columnas con texto son object y el resto está como float.
# Ahora hay que eliminar valores duplicados y luego los ausentes.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
print(pedidos_instacart.duplicated().sum())
duplicados = pedidos_instacart[pedidos_instacart.duplicated(keep=False)]
print(duplicados)
# Out:
# 15
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 30371    1918001   188546            14          3                  2
# 99462     794638    50898            24          3                  2
# 119251    408114    68324             4          3                  2
# 142258   2845099    31189            11          3                  2
# 145574    794638    50898            24          3                  2
# 164581   1112182   202304            84          3                  2
# 200059   1782114   106752             1          3                  2
# 204042   2125197    14050            48          3                  2
# 215294   2160484   107525            16          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 242618   1021560    53767             3          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
# Tienen en común que todas son del día miércoles a las 2 a.m.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
pedidos_miercoles = pedidos_instacart[pedidos_instacart['order_dow'] == 3] #para obtener solo el día miércoles

miercoles_2am = pedidos_miercoles[pedidos_miercoles['order_hour_of_day'] == 2] #para obtener los pedidos de las 2 am

print(miercoles_2am)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado? que no todos los pedidos del día miércoles a las 2 a.m son duplicados, son solo 15 de 121 pedidos.

# %%
# Elimina los pedidos duplicados
pedidos_instacart = pedidos_instacart.drop_duplicates()

# %%
# Vuelve a verificar si hay filas duplicadas
print(pedidos_instacart.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
print(pedidos_instacart['order_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos:
# Entonces, primero pedí que me diera el número total de filas duplicadas, luego hice que estas se imprimieran para ver dónde estaba el problema.
# Luego, el proyecto me sugirió solo ver las filas y columnas de los días miércoles a las 2 a.m puesto que a esa hora fue donde se generaron pedidos duplicados. Se obtuvo que ese día a esa hora hubo 121 pedidos, pero de los cuáles solo 15 estaban duplicados.
# Después, se eliminaron estas filas duplicadas y se verificó si seguían habiendo filas duplicadas con duplicated().sum() y, concretamente, si había pedidos duplicados aplicandolo solo a la columna order_id.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Flujo de trabajo sólido de investigación de duplicados para la tabla `orders`: cuantificaste los duplicados, los inspeccionaste, validaste el patrón de miércoles a las 2am, eliminaste los duplicados y volviste a comprobar tanto la duplicación de la fila completa como la duplicación por `order_id`.
#
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print(productos.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay ID de productos duplicados
print(productos['product_id'].duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
productos['product_name'] = productos['product_name'].str.upper() #convertir a mayus con str.upper
print(productos['product_name'].head())
print()
print(productos['product_name'].duplicated().sum())
# Out:
# 0                           CHOCOLATE SANDWICH COOKIES
# 1                                     ALL-SEASONS SALT
# 2                 ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3    SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# 4                            GREEN CHILE ANYTIME SAUCE
# Name: product_name, dtype: object
#
# 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
duplicados_product = productos[productos['product_name'].notna() & 
    productos['product_name'].duplicated(keep=False)
] ##aquí se combina la condición de filtrar por productos no faltantes y marcar los duplicados
print(duplicados_product)

duplicados_unicos = productos['product_name'].value_counts()
duplicados_unicos = duplicados_unicos[duplicados_unicos > 1]

print(len(duplicados_unicos))
# Out:
#        product_id                                     product_name  aisle_id  \
# 41             42                                  BIOTIN 1000 MCG        47
# 185           186       FRESH SCENT DISHWASHER DETERGENT WITH DAWN        74
# 515           516                           AMERICAN CHEESE SLICES        21
# 1538         1539                                 CAULIFLOWER HEAD        83
# 1783         1784              NUTRITION PROTEIN MIX BLUEBERRY NUT       117
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 41                11
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Aquí el objetivo es comprobar valores duplicados de `product_name` *no faltantes* después de normalizar mayúsculas/minúsculas. Ahora mismo estás volviendo a comprobar duplicados de toda la fila, así que en realidad no identificas nombres duplicados excluyendo NaNs. Considera filtrar con `product_name.notna()` y luego comprobar duplicados en esa columna.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Primero, se hizo una obtención simple de las filas duplicadas en el DataFrame "productos". Se obtuvo 0 duplicados, pero, se pidió cambiar todos los nombres de productos a mayusculas, ya que quizás podrían haber duplicados implícitos al haber nombres de un mismo producto en minúscula y mayúscula a la vez.
# Luego de cambiar todos los nombres a mayúsculas con .str.upper() se vuelve a verificar si hay filas duplicadas, y siguen habiendo 0.
# Luego, revisando los duplicados de productos no faltantes, se obtienen 1465 filas de datos con duplicados, pero valores únicos duplicados son 104.

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(departamentos.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
print(departamentos['department_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - En este caso, no hay valores duplicados en el DataFrame de departamentos. Tanto en las filas completas como si uno solo observa la columna 'department_id'. Esta última siendo importante de verificar, ya que solo debería haber 1 id por departamento. Además, al ser un número entero, no se corre el riesgo de los string de que pueda haber algunos valores con minúsculas y otros con mayúsculas.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(pasillo.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
print(pasillo['aisle_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto, no hay duplicados en _departments_ ni en _aisles_.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Primero se revisa si hay filas enteras duplicadas con duplicated().sum(), y no se encuentra ninguna. Luego, se hace el mismo procedimiento pero solo para los aisle_id, que en teoria, no deberían estar duplicados, pero tampoco había ninguno, por lo que está todo bien con este DF.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(pedidos.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
print(pedidos['order_id'].duplicated().sum()) 

num_duplicados = pedidos.duplicated(
    subset=['order_id', 'product_id', 'add_to_cart_order']
).sum()

print(num_duplicados)
# Out:
# 4094961
# 0

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# En `order_products`, se esperan valores repetidos de `order_id` porque cada pedido puede contener varias filas de productos. En cambio, la verificación de “tricky duplicates” trata de filas realmente duplicadas o de duplicados en una clave compuesta (por ejemplo, la combinación de `order_id` + `product_id` + `add_to_cart_order`).
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos:
# - Aqui se observa que para la columna order_id hay muchos valores duplicados. Se entiende porque un pedido puede tener varios productos asociados (product_id). Se revisó también la combinación order_id, product_id y add_to_cart_order y no hay duplicados.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# En tu resumen escrito, aclara que los valores de `order_id` duplicados son normales en `order_products`; luego, confirma si existen duplicados *reales* (duplicados de fila completa o de clave compuesta) y si los eliminaste.
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
print(productos.isna().sum())
# Out:
# product_id          0
# product_name     1258
# aisle_id            0
# department_id       0
# dtype: int64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos:
# - Se puede observar que solo la columna 'product_name' tiene valores ausentes, 1258 en total.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?

productos_ID100 = productos[productos['aisle_id'] == 100]
print(productos_ID100.count())
print(productos_ID100.head())
print(productos_ID100.tail())
# Out:
# product_id       1258
# product_name        0
# aisle_id         1258
# department_id    1258
# dtype: int64
#      product_id product_name  aisle_id  department_id
# 37           38          NaN       100             21
# 71           72          NaN       100             21
# 109         110          NaN       100             21
# 296         297          NaN       100             21
# 416         417          NaN       100             21
#        product_id product_name  aisle_id  department_id
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos:
# - Al definir un DataFrame solo con las filas del pasillo 100, se pudo obtener que la columna 'product_name' no tiene valores y si uno imprime las primeras y últimas 5 filas, se observa que todos sus valores son NaN. Efectivamente puede haber una relación entre el pasillo 100 y los valores ausentes.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
productos_ID21 = productos[productos['department_id'] == 21]
print(productos_ID21.count())
print(productos_ID21.head())
print(productos_ID21.info())
# Out:
# product_id       1258
# product_name        0
# aisle_id         1258
# department_id    1258
# dtype: int64
#      product_id product_name  aisle_id  department_id
# 37           38          NaN       100             21
# 71           72          NaN       100             21
# 109         110          NaN       100             21
# 296         297          NaN       100             21
# 416         417          NaN       100             21
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1258 entries, 37 to 49668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     1258 non-null   int64
#  1   product_name   0 non-null      object
#  2   aisle_id       1258 non-null   int64
#  3   department_id  1258 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 49.1+ KB
# None

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos:
# - Al definir un DataFrame solo con las filas del departamento 21, se pudo obtener que la columna 'product_name' no tiene valores y si uno imprime las primeras y últimas 5 filas, se observa que todos sus valores son NaN. Efectivamente puede haber una relación entre el departamento 21 y los valores ausentes.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
print(productos_ID100.head())
print(productos_ID21.head())
# Out:
#      product_id product_name  aisle_id  department_id
# 37           38          NaN       100             21
# 71           72          NaN       100             21
# 109         110          NaN       100             21
# 296         297          NaN       100             21
# 416         417          NaN       100             21
#      product_id product_name  aisle_id  department_id
# 37           38          NaN       100             21
# 71           72          NaN       100             21
# 109         110          NaN       100             21
# 296         297          NaN       100             21
# 416         417          NaN       100             21

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este paso te pide que uses las tablas `aisles` y `departments` para consultar qué representan `aisle_id=100` y `department_id=21` (sus nombres) e informar qué implica eso sobre los valores faltantes de `product_name`. Por favor, muestra los resultados de la consulta y añade una breve interpretación en la siguiente celda de markdown.
#
# </div>

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. Están relacionados el pasillo 100 con el departamento 21.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
productos['product_name'] = productos['product_name'].fillna('Unknown')
print(productos.isna().sum())
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Las instrucciones especifican rellenar los nombres de productos faltantes con el marcador de posición exacto `'Unknown'`. Usar una capitalización/valor diferente (p. ej., `'unknown'`) hace que tu resultado sea inconsistente con los requisitos del proyecto.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al identificar los valores ausentes en `product_name` y asociarlos con las columnas `aisle_id` y `department_id`! Reemplazar estos valores con `'Unknown'` es una decisión lógica y adecuada.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos:
# - Cambie los valores ausentes por unknown y luego volví a revisar que hubiera valores ausentes y ahora no hay ninguno para todas las columnas.

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print(pedidos_instacart.isna().sum())
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
no_primer_pedido = pedidos_instacart[pedidos_instacart['order_number'] > 1]
print(no_primer_pedido.head())
print(no_primer_pedido.info())
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450135 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                450135 non-null  int64
#  1   user_id                 450135 non-null  int64
#  2   order_number            450135 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este paso pregunta si algún valor faltante de `days_since_prior_order` aparece más allá del primer pedido de un cliente. Actualmente solo muestras los primeros pedidos; por favor, verifícalo explícitamente filtrando las filas donde falta `days_since_prior_order` y comprobando si alguna tiene `order_number > 1`, y luego indica la conclusión.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos:
# - Filtrando por la tabla  donde 'order_number' > 1, no hay valores ausentes. Esto se hizo pensando en que days_since_prior_order si o si va a ser ausente para la primera compra, entonces solo se consideraron las filas desde la segunda orden.
# - Prefiero dejar por ahora los valores ausentes como NaN, ya que puede ser confuso ponerle 0 por ejemplo, si se hacen 2 pedidos el mismo día que se hizo la primera compra.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Describes lo que encontraste, pero por favor también explica qué decidiste hacer con los valores faltantes de `days_since_prior_order` (p. ej., mantenerlos como NaN para los primeros pedidos, o imputarlos/rellenarlos) y por qué esa elección tiene sentido para este conjunto de datos.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
print(pedidos.isna().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print(pedidos.info())
print(pedidos.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None
#            order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# std    9.850955e+05  1.409552e+04       7.080368e+00  4.917411e-01
# min    4.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.608170e+05  1.353500e+04       3.000000e+00  0.000000e+00
# 50%    1.711530e+06  2.527200e+04       6.000000e+00  1.000000e+00
# 75%    2.561311e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421079e+06  4.969400e+04       6.400000e+01  1.000000e+00

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos:
# - Los valores mínimos de la columna add_to_cart_order es 1 y el valor máximo es 64. Esto se obtuvo primero identificando el tipo de variable que es (en este caso float) y luego aplicando describe(), para variables numéricas.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
pedidos_ATCO_ausentes = pedidos[pedidos['add_to_cart_order'].isna()]
print(pedidos_ATCO_ausentes.head())
# Out:
#        order_id  product_id  add_to_cart_order  reordered
# 737     2449164        5068                NaN          0
# 9926    1968313       43867                NaN          0
# 14394   2926893       11688                NaN          0
# 16418   1717990        4142                NaN          0
# 30114   1959075       42828                NaN          1

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
ATCO_ausentes_per_product = pedidos_ATCO_ausentes.groupby('order_id')['product_id']
print(ATCO_ausentes_per_product.count().sort_values(ascending=True))
# Out:
# order_id
# 9310        1
# 747668      1
# 1598369     1
# 1677118     1
# 2170451     1
#            ..
# 1959075    34
# 171934     40
# 2136777    44
# 3308010    51
# 61355      63
# Name: product_id, Length: 70, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta verificación no está completada en el código: necesitas agrupar los pedidos con `add_to_cart_order` faltante, contar los ítems por `order_id` y comprobar si todos esos pedidos tienen más de 64 productos (y reportar el conteo mínimo a partir de ese resultado agrupado). Tu resumen en markdown hace referencia a resultados, pero el cálculo requerido no se muestra en este paso.
#
# </div>

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos:
# - Al agrupar por order_id y contando los productos con product_id y count, cada orden tiene distinta cantidad de productos.
# - Al ordenarlos de forma ascendente se observa que la cantidad mínima de productos es 1 y la cantidad máxima es de 63 productos.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
pedidos['add_to_cart_order'] = pedidos['add_to_cart_order'].fillna(999)
pedidos['add_to_cart_order'] = pedidos['add_to_cart_order'].astype(int)
print(pedidos['add_to_cart_order'].dtypes)
print(pedidos.isna().sum())
# Out:
# int64
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo!
#
# Un valor mínimo de 1 tiene sentido porque cada pedido necesita, al menos, 1 artículo. Pero, un valor máximo de 64 resulta un tanto curioso. No hay ninguna razón (que no sea mera suerte) para que cualquiera pidiera más de 64 artículos en un pedido.
#
# Además, 64 enciende las alarmas porque es un número de base 2 muy común que surgen con asuntos de informática. Esta es una pista de que quizás el tipo database para esa columna solo admite almacenamiento de 64 bits.
#
# Luego, como era de esperarse, cada pedido relacionado con un valor ausente tiene más de 64 artículos en ella.
#
# Ya que no podemos saber en qué pedido se agregaron al carrito los artículos con valores ausentes para aquellos pedidos con más de 65 artículos, lo correcto es completar los valores ausentes con un valor de marcador de posición numérico que no pueda confundirse con daros reales; por ejemplo, 999.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos:
# - con la opción fillna(), cambié los valores ausentes de la columna add_to_cart_order por 999, después cambié el tipo de dato de float a int con astype(), luego lo confirmé imprimiendo dtypes y finalmente, me aseguré que no hayan valores ausentes volviendo a imprimir isna().sum()

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos:
# - Se pudo realizar los arreglos necesarios en cuanto a valores ausentes y duplicados con distintas técnicas. En general, casi todos se gestionaron de forma similar, excepto por un par de columnas que merecían un análisis más específico como add_to_chart_order donde obviamente iba a haber valores ausentes o days_since_prior_order donde si había una primera order de un cliente estaba como NaN.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print(pedidos_instacart['order_hour_of_day'].describe())
print(pedidos_instacart['order_dow'].describe())

pedidos_instacart['order_hour_of_day'] = pedidos_instacart['order_hour_of_day'].astype(int)
print(pedidos_instacart['order_hour_of_day'].head())

pedidos_instacart['order_dow'] = pedidos_instacart['order_dow'].astype(int)
print(pedidos_instacart['order_dow'].head())
# Out:
# count    478952.000000
# mean         13.447034
# std           4.224567
# min           0.000000
# 25%          10.000000
# 50%          13.000000
# 75%          16.000000
# max          23.000000
# Name: order_hour_of_day, dtype: float64
# count    478952.000000
# mean          2.775051
# std           2.045901
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%           5.000000
# max           6.000000
# Name: order_dow, dtype: float64
# 0    13
# 1    12
# 2    19
# 3    20
# 4    12
# Name: order_hour_of_day, dtype: int64
# 0    6
# 1    5
# 2    5
# 3    0
# 4    4
# Name: order_dow, dtype: int64

# %%
personas_por_hora = pedidos_instacart.groupby('order_hour_of_day')['user_id'].nunique()
personas_por_hora.plot(title='Pedidos al día', xlabel='Hora del día', ylabel='N° de personas', rot=50, kind='bar')
plt.show()


personas_por_dia = pedidos_instacart.groupby('order_dow')['user_id'].nunique()
personas_por_dia.plot(title='Pedidos a la semana', xlabel='Día de la semana', ylabel='N° de personas', rot=50, kind='bar')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones: Más o menos de 7 am a 21 pm se hacen más pedidos. El histograma muestra al parecer una distribución normal sesgada a la derecha. Y, según el gráfico de pedidos por día de la semana, se hacen más pedidos los días domingos y lunes, pero en general, es bastante constante.

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
tabla_pedidos = personas_por_hora.reset_index()
tabla_pedidos.columns = ['hora_del_dia', 'cantidad_pedidos']

print(tabla_pedidos)
# Out:
#     hora_del_dia  cantidad_pedidos
# 0              0              2991
# 1              1              1671
# 2              2               958
# 3              3               744
# 4              4               735
# 5              5              1281
# 6              6              3757
# 7              7             10993
# 8              8             20268
# 9              9             28112
# 10            10             32195
# 11            11             32660
# 12            12             31754
# 13            13             32433
# 14            14             32797
# 15            15             32894
# 16            16             31579
# 17            17             26825
# 18            18             21795
# 19            19             17026
# 20            20             12891
# 21            21              9806
# 22            22              7670
# 23            23              5167

# %% [markdown]
# La mayoría de los pedidos se realizan entre las 8.00 am y las 18.00 hrs (sobre 20000 pedidos), disminuyendo gradualmente después de las 18 hrs. En la magrudada, de 00:00 a 06:00 son muy bajos (menos de 4000 pedidos).
# Entre las 10 am y 16 hrs, es donde más pedidos se hacen, sobre los 30 mil pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo al responder [A2]: contar usuarios únicos por hora, presentar los resultados con claridad e interpretar con precisión las horas pico de pedidos.
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
tabla_pedidos_dia = personas_por_dia.reset_index()
tabla_pedidos_dia.columns = ['dia', 'cantidad_pedidos']

print(tabla_pedidos_dia)
# Out:
#    dia  cantidad_pedidos
# 0    0             57661
# 1    1             56479
# 2    2             48587
# 3    3             45331
# 4    4             44281
# 5    5             46127
# 6    6             45604

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo en [A3]: agrupaste por `order_dow`, usaste `nunique()` para contar usuarios únicos y presentaste una tabla clara que coincide con tu interpretación.
#
# </div>

# %% [markdown]
# Todos los días de la semana se realizan bastantes pedidos, siendo constantes durante toda la semana, pero con un leve aumento los días domingo (índice 0) y lunes (índice 1).

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
#excluir primeros pedidos
pedidos_sin_NaN = pedidos_instacart[pedidos_instacart["days_since_prior_order"].notna()]

#Cálculo de tiempos mínimos y máximos
tiempo_min = pedidos_sin_NaN["days_since_prior_order"].min()
tiempo_max = pedidos_sin_NaN["days_since_prior_order"].max()
print(f"Tiempo mínimo entre pedidos: {tiempo_min} días")
print(f"Tiempo máximo entre pedidos: {tiempo_max} días")

#Gráfico de la distribución de tiempo entre pedidos
hist_pedidos = pedidos_sin_NaN["days_since_prior_order"].plot(kind="hist", bins=30, figsize=(10, 6),
    color="skyblue", edgecolor="black", alpha=0.7)

plt.title("Distribución del tiempo de espera entre pedidos")
plt.xlabel("Días desde el pedido anterior")
plt.ylabel("Frecuencia")

plt.legend()
plt.show()
# Out:
# Tiempo mínimo entre pedidos: 0.0 días
# Tiempo máximo entre pedidos: 30.0 días

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Falta la tarea [A4]. Usa la columna `days_since_prior_order` de la tabla orders para graficar la distribución del tiempo de espera entre pedidos (normalmente excluyendo los primeros pedidos, donde es NaN) e informa explícitamente los tiempos de espera mínimo y máximo que observes.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones: Una buena cantidad de personas, vuelve a realizar pedidos los primeros 10 días desde la orden anterior, pero también llama la atención que la cantidad de personas que piden cada 30 días es super alta (alrededor de 50).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al visualizar los datos! Además, tu interpretación de los resultados es sólida
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
# Filtrar datos para miercoles y sabado
miercoles = pedidos_instacart[pedidos_instacart['order_dow'] == 3]
sabado = pedidos_instacart[pedidos_instacart['order_dow'] == 6]

# %%
# Agrupar por hora
pedidos_miercoles = miercoles.groupby('order_hour_of_day')['user_id'].nunique()
pedidos_sabado = sabado.groupby('order_hour_of_day')['user_id'].nunique()

# %%
## Considerar todas las horas del día
pedidos_miercoles = pedidos_miercoles.reindex(range(24), fill_value=0)
pedidos_sabado = pedidos_sabado.reindex(range(24), fill_value=0)

# %%
## Crear gráfico

x = range(24)

plt.figure(figsize=(12,6))

plt.bar(x, pedidos_miercoles, alpha=0.6, label='Miércoles', color='blue')
plt.bar(x, pedidos_sabado, alpha=0.6, label='Sábado', color='pink')

plt.xlabel('Hora del día'); plt.ylabel('Cantidad de pedidos'); plt.title('Pedidos por hora: Miércoles vs Sábado'); plt.xticks(range(24)); plt.legend()

plt.show()

# %% [markdown]
# La distribución entre ambos días por hora son bastante similares. Salvo por un par de horas, entre las 12.00 y las 14.00 hrs, donde aumenta más la cantidad de pedidos los días sábado.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo en [B1]: filtraste correctamente miércoles vs. sábado, alineaste las 24 horas, graficaste ambas distribuciones con un etiquetado claro y resumiste la diferencia de forma concisa.
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
## agrupar pedidos por cliente
pedidos_por_cliente = pedidos_instacart.groupby('user_id')['order_id'].count()

# %%
### clientes por cantidad de pedidos (1, 2, 3, etc.)

clientes_por_num_pedidos = pedidos_por_cliente.value_counts().sort_index()

print(clientes_por_num_pedidos)
# Out:
# 1     55357
# 2     36508
# 3     21547
# 4     13498
# 5      8777
# 6      6012
# 7      4240
# 8      3019
# 9      2152
# 10     1645
# 11     1308
# 12      947
# 13      703
# 14      512
# 15      437
# 16      263
# 17      184
# 18      121
# 19       85
# 20       52
# 21       22
# 22       23
# 23       19
# 24        3
# 25        1
# 26        1
# 28        1
# Name: order_id, dtype: int64

# %%
## graficar

plt.figure(figsize=(10,6))

plt.bar(clientes_por_num_pedidos.index, clientes_por_num_pedidos.values)

plt.xlabel('Número de pedidos'); plt.ylabel('Cantidad de clientes'); plt.title('Clientes según número de pedidos')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Solución sólida [B2]: calculaste la distribución de pedidos por cliente, la graficaste con etiquetas y explicaste claramente el patrón general.
#
# </div>

# %% [markdown]
# Se genera una curva exponencial entre el número de pedidos y la cantidad de clientes que piden esa cantidad de pedidos. Se observa que la mayoría de los clientes hace pedidos solo una vez. Luego va disminuyendo exponencialmente, donde, por ejemplo, solo un par de clientes hace más de 10 pedidos, hasta volverse nulo después de los 18 pedidos.

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
## veces que se ha comprado cada producto
veces_por_producto = (pedidos.groupby('product_id').size().reset_index(name='veces_pedido'))

# %%
## escoger los 20 productos más populares
mejores_20 = (veces_por_producto.sort_values(by='veces_pedido', ascending=False).head(20))

# %%
## unir con datos de 'products' para aclar con nombre de productos
mejores_20 = mejores_20.merge(productos, on='product_id')

# %%
## crear lista de productos
mejores_20 = mejores_20[['product_id', 'product_name', 'veces_pedido']]
print(mejores_20)
# Out:
#     product_id              product_name  veces_pedido
# 0        24852                    BANANA         66050
# 1        13176    BAG OF ORGANIC BANANAS         53297
# 2        21137      ORGANIC STRAWBERRIES         37039
# 3        21903      ORGANIC BABY SPINACH         33971
# 4        47209      ORGANIC HASS AVOCADO         29773
# 5        47766           ORGANIC AVOCADO         24689
# 6        47626               LARGE LEMON         21495
# 7        16797              STRAWBERRIES         20018
# 8        26209                     LIMES         19690
# 9        27845        ORGANIC WHOLE MILK         19600
# 10       27966       ORGANIC RASPBERRIES         19197
# 11       22935      ORGANIC YELLOW ONION         15898
# 12       24964            ORGANIC GARLIC         15292
# 13       45007          ORGANIC ZUCCHINI         14584
# 14       39275       ORGANIC BLUEBERRIES         13879
# 15       49683            CUCUMBER KIRBY         13675
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo en [B3]: identificaste correctamente los 20 productos más solicitados con mayor frecuencia y mostraste tanto los IDs como los nombres de los productos.
#
# </div>

# %% [markdown]
# Lo que más se pide son básicamente frutas y verduras. Se puede notar una clara preferencia por prodcutos orgánicos. Y el best-seller sería el plátano normal y orgánico.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
### cantidad de productos por pedido (order_id)
productos_por_pedido = (pedidos.groupby('order_id').size().reset_index(name='num_productos'))

# %%
## Gráfico de distribución (histograma)
plt.figure()
plt.hist(productos_por_pedido['num_productos'], bins=50)
plt.title('Cantidad de productos por pedido')
plt.xlabel('Número de productos por pedido')
plt.ylabel('Cantidad de pedidos')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo en [C1]: calculaste correctamente los artículos por pedido y visualizaste la distribución con un histograma debidamente etiquetado.
#
# </div>

# %% [markdown]
# Se observa claramente que la mayoría de personas pide menos de 12 productos por pedido. Luego hay una clara tendencia a la baja.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo en [C2]: filtraste los ítems reordenados, contaste por `product_id`, seleccionaste el top 20 y combinaste (merge) para mostrar tanto los IDs de producto como los nombres en un resultado claro.
#
# </div>

# %%
# Filtrar productos reordenados (valor 1)
productos_repedidos = pedidos[pedidos['reordered'] == 1]

# %%
## Obtener cuantas veces se reordenó un producto
conteo_de_repedidos = (productos_repedidos.groupby('product_id').size().reset_index(name='conteo_de_repedido'))

# %%
## Obtener los 20 más revendidos
top_20_revendidos = (conteo_de_repedidos.sort_values(by='conteo_de_repedido', ascending=False).head(20))

# %%
## Unir con product_name y mostrar en lista
top_20_revendidos = top_20_revendidos.merge(productos, on='product_id')
top_20_revendidos = top_20_revendidos[['product_id', 'product_name', 'conteo_de_repedido']]
print(top_20_revendidos)
# Out:
#     product_id              product_name  conteo_de_repedido
# 0        24852                    BANANA               55763
# 1        13176    BAG OF ORGANIC BANANAS               44450
# 2        21137      ORGANIC STRAWBERRIES               28639
# 3        21903      ORGANIC BABY SPINACH               26233
# 4        47209      ORGANIC HASS AVOCADO               23629
# 5        47766           ORGANIC AVOCADO               18743
# 6        27845        ORGANIC WHOLE MILK               16251
# 7        47626               LARGE LEMON               15044
# 8        27966       ORGANIC RASPBERRIES               14748
# 9        16797              STRAWBERRIES               13945
# 10       26209                     LIMES               13327
# 11       22935      ORGANIC YELLOW ONION               11145
# 12       24964            ORGANIC GARLIC               10411
# 13       45007          ORGANIC ZUCCHINI               10076
# ...

# %% [markdown]
# El resultado es muy similar a los obtenidos en la lista de los 20 pedidos más vendidos. Lo que quiere decir que la gente vuelve a pedir los mismos productos, vale decir, frutas y verduras orgánicas y unas cuantas otras frutas/verduras no orgánicas.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
## En este caso la tasa de repetición del pedido (%) sería el número de veces que fue repedido sobre
## el total de veces que fue pedido y así se puede visualizar los productos que se vuelven a 
## comprar y cuáles no tanto.

# %%
# total de veces que un producto fue pedido
total_de_pedidos = (pedidos.groupby('product_id').size().reset_index(name='total_pedidos'))

# %%
## total de veces que un producto fue reordenado/repedido
repedidos = (pedidos[pedidos['reordered'] == 1]
    .groupby('product_id').size().reset_index(name='conteo_repedidos'))

# %%
## Unir total de pedidos y productos reordenados en una tabla
tasa_de_repedidos = total_de_pedidos.merge(repedidos, on='product_id', how='left')

##Crear tasa
tasa_de_repedidos['tasa_de_repedidos'] = (
    tasa_de_repedidos['conteo_repedidos'] / tasa_de_repedidos['total_pedidos'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Como usaste un **left join**, los productos con cero reorders tendrán recuentos de reorders faltantes y su tasa de reorder se convierte en NaN. Trata esos recuentos de reorders faltantes como 0 para que cada producto tenga una proporción de reorder válida, incluidos los artículos que nunca se reordenaron.
#
# </div>

# %%
# Agregar columna con los nombres de productos
tasa_de_repedidos = tasa_de_repedidos.merge(productos, on='product_id')

# %%
## generar las columnas
tasa_de_repedidos = tasa_de_repedidos[['product_id', 'product_name', 'tasa_de_repedidos']]

print(tasa_de_repedidos.sort_values(by='tasa_de_repedidos', ascending=False).head())
# Out:
#        product_id                                       product_name  \
# 10973       12038           FOR WOMEN MAXIMUM ABSORBENCY L UNDERWEAR
# 1646         1809  SLOW KETTLE STYLE SANTA FE CHICKEN ENCHILADA S...
# 33130       36122                                  SPICY CHILI BEANS
# 2929         3205            ORIGINAL PURE CHOCOLATE WHIPPET COOKIES
# 38398       41901   MOISTURIZING LOTIONIZED SHAVE GEL WITH VITAMIN E
#
#        tasa_de_repedidos
# 10973                1.0
# 1646                 1.0
# 33130                1.0
# 2929                 1.0
# 38398                1.0

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
## primero unimos los dos datasets pedidos y pedidos_instacart
pyp = pedidos.merge(pedidos_instacart[['order_id', 'user_id']], on='order_id')

# %%
## Total de productos comprados por cliente
items_totales = (pyp.groupby('user_id').size().reset_index(name='items_totales'))

# %%
## total de productos repedidos por los clientes
items_repedidos = (pyp[pyp['reordered'] == 1].groupby('user_id').size().reset_index(name='items_repedidos'))

# %%
## unir ambos totales en una tabla
tasa_repedidos_usuarios = items_totales.merge(items_repedidos, on='user_id', how='left')

# %%
## generar la tasa
tasa_repedidos_usuarios['tasa_repedidos'] = (tasa_repedidos_usuarios['items_repedidos'] / tasa_repedidos_usuarios['items_totales'])
print(tasa_repedidos_usuarios.tail())
# Out:
#         user_id  items_totales  items_repedidos  tasa_repedidos
# 149621   206203             27              6.0        0.222222
# 149622   206206             21             15.0        0.714286
# 149623   206207             46             41.0        0.891304
# 149624   206208            125             87.0        0.696000
# 149625   206209             25              8.0        0.320000

# %% [markdown]
# Aquí entonces se tiene la tabla con los valores de la tasa de productos reordenados/repedidos. Al ser muchos clientes (206209), es dificil observar una tendencia, a no ser que se genere un gráfico. De todas maneras, se entiende que una tasa cercana a 1 (o 100%) son clientes que recompran casi todos sus productos y una tasa cercana a 0 son clientes que van comprando diferentes productos.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
## Primero se filtra por 'add_to_cart_order' para obtener los productos que se añadieron primero
primer_producto = pedidos[pedidos['add_to_cart_order'] == 1]

# %%
## contar cuantas veces se repiten estos productos por product_id
repeticion_primeros = (primer_producto.groupby('product_id').size().reset_index(name='veces_primero'))

# %%
## seleccionar solo los 20 mejores
top_20 = (repeticion_primeros.sort_values(by='veces_primero', ascending=False).head(20))

# %%
## unir los top_20 con el nombre de los productos
top_20 = top_20.merge(productos, on='product_id')

# %%
## seleccionar las columnas e imprimir
top_20 = top_20[['product_id', 'product_name', 'veces_primero']]
print(top_20)
# Out:
#     product_id                 product_name  veces_primero
# 0        24852                       BANANA          15562
# 1        13176       BAG OF ORGANIC BANANAS          11026
# 2        27845           ORGANIC WHOLE MILK           4363
# 3        21137         ORGANIC STRAWBERRIES           3946
# 4        47209         ORGANIC HASS AVOCADO           3390
# 5        21903         ORGANIC BABY SPINACH           3336
# 6        47766              ORGANIC AVOCADO           3044
# 7        19660                 SPRING WATER           2336
# 8        16797                 STRAWBERRIES           2308
# 9        27966          ORGANIC RASPBERRIES           2024
# 10       44632   SPARKLING WATER GRAPEFRUIT           1914
# 11       49235          ORGANIC HALF & HALF           1797
# 12       47626                  LARGE LEMON           1737
# 13         196                         SODA           1733
# 14       38689     ORGANIC REDUCED FAT MILK           1397
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo en [C5]: filtrar `add_to_cart_order == 1`, calcular el top 20 y presentar los IDs de producto, nombres y conteos cumple con los requisitos de la tarea.
#
# </div>

# %% [markdown]
# Este top 20 es bastante similar a los otros top 20 obtenidos (pedidos que vuelven a pedirse y pedidos que más se compran). Hay leves diferencia, pero sigue habiendo una tendencia por pedir plátanos en primero lugar y productos orgánicos.

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Fue un proyecto bastante completo, donde hay que poner a prueba muchos conocimientos desde los primeros sprint.
# Muy desafiante, pero entretenido porque muestra (creo yo), cómo sería en un empleo real. También me hizo darme cuenta que hay mucho más que aprender para poder aplicar estos códigos, pero de forma más eficiente.
#
# Respecto al proyecto en sí, se logró determinar muchos comportamientos de los clientes, lo que puede ayudar mucho a futuro a generar decisiones empresariales.
#
# Sí hubo varios valores ausentes, duplicados y mal escritos, que podrían disminuir en una futura toma de datos.
#
# Dentro del autoanálisis también me di cuenta que fue innecesario cambiar de nombre los archivos. Por ejemplo, order_productos a pedidos. Al final, me

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu conclusión final está escrita en una celda de código, por lo que no está formateada como se pretende. Considera moverla a una celda de Markdown y resumir algunos hallazgos concretos de tu análisis (además de las decisiones clave de limpieza de datos que tomaste).
#
# </div>
